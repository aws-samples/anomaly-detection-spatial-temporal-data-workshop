# %%
import sys
sys.path.append("../../src/")

# %%
from anomaly_detection_spatial_temporal_data.model.time_series import NABAnomalyDetector

# %%
import pandas as pd

# %% [markdown]
# # Train NAB Context OSE model

# %%
model_name = "contextOSE"
model_path = "../../src/anomaly_detection_spatial_temporal_data/model/NAB"
input_dir = "../../data/02_intermediate/iot/ts_data"
label_file = "../../data/02_intermediate/iot/ts_label/labels-test.json"
output_dir =  "../../data/07_model_output/iot/ts_result-notebook"

# %%
nab = NABAnomalyDetector(
    model_name, 
    model_path,
    input_dir,
    label_file,
    output_dir,
)

# %%
nab.predict()
# Out:
# Predicting ...
# 6: Beginning detection with contextOSE for S_PU7.csv
# . 0: Beginning detection with contextOSE for S_PU5.csv
# . 12: Beginning detection with contextOSE for S_PU3.csv
# . 8: Beginning detection with contextOSE for L_T4.csv
# . 2: Beginning detection with contextOSE for S_PU10.csv
# . 4: Beginning detection with contextOSE for S_PU11.csv
# . 10: Beginning detection with contextOSE for F_PU9.csv
# . 14: Beginning detection with contextOSE for S_PU8.csv
# . . . . . . . 0: Completed processing 2089 records at 2022-07-23 00:13:14.145183
# 0: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU5.csv
# 1: Beginning detection with contextOSE for L_T1.csv
# . . . 12: Completed processing 2089 records at 2022-07-23 00:13:14.172055
# 12: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU3.csv
# 13: Beginning detection with contextOSE for P_J415.csv
# . 10: Completed processing 2089 records at 2022-07-23 00:13:14.210376
# 10: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU9.csv
# 11: Beginning detection with contextOSE for S_PU2.csv
# . 4: Completed processing 2089 records at 2022-07-23 00:13:14.210377
# 4: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU11.csv
# 5: Beginning detection with contextOSE for F_V2.csv
# . . . . . . . . . 14: Completed processing 2089 records at 2022-07-23 00:13:16.521717
# 14: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU8.csv
# 15: Beginning detection with contextOSE for L_T5.csv
# . . . 11: Completed processing 2089 records at 2022-07-23 00:13:18.132341
# 11: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU2.csv
# 16: Beginning detection with contextOSE for P_J14.csv
# . . 1: Completed processing 2089 records at 2022-07-23 00:13:18.345463
# 1: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T1.csv
# 18: Beginning detection with contextOSE for P_J422.csv
# . . . 6: Completed processing 2089 records at 2022-07-23 00:13:18.726513
# 6: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU7.csv
# 7: Beginning detection with contextOSE for P_J269.csv
# . 2: Completed processing 2089 records at 2022-07-23 00:13:18.849294
# 2: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU10.csv
# 3: Beginning detection with contextOSE for F_PU6.csv
# . . . . 3: Completed processing 2089 records at 2022-07-23 00:13:19.213942
# 3: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU6.csv
# 20: Beginning detection with contextOSE for S_PU6.csv
# . . . 20: Completed processing 2089 records at 2022-07-23 00:13:19.446628
# 20: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU6.csv
# 21: Beginning detection with contextOSE for P_J289.csv
# . . 5: Completed processing 2089 records at 2022-07-23 00:13:19.541534
# 5: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_V2.csv
# 22: Beginning detection with contextOSE for P_J300.csv
# . . . . 13: Completed processing 2089 records at 2022-07-23 00:13:20.396193
# 13: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J415.csv
# 24: Beginning detection with contextOSE for P_J256.csv
# . . . . . . 7: Completed processing 2089 records at 2022-07-23 00:13:22.590434
# 7: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J269.csv
# 26: Beginning detection with contextOSE for L_T2.csv
# . . 18: Completed processing 2089 records at 2022-07-23 00:13:23.190118
# 18: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J422.csv
# 19: Beginning detection with contextOSE for P_J317.csv
# . . . 21: Completed processing 2089 records at 2022-07-23 00:13:24.434200
# 21: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J289.csv
# 28: Beginning detection with contextOSE for L_T6.csv
# . 22: Completed processing 2089 records at 2022-07-23 00:13:24.619617
# 22: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J300.csv
# 23: Beginning detection with contextOSE for S_PU1.csv
# . . . 23: Completed processing 2089 records at 2022-07-23 00:13:24.851576
# 23: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU1.csv
# 30: Beginning detection with contextOSE for L_T3.csv
# . . . . 15: Completed processing 2089 records at 2022-07-23 00:13:25.939360
# 15: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T5.csv
# 32: Beginning detection with contextOSE for L_T7.csv
# . . 24: Completed processing 2089 records at 2022-07-23 00:13:26.765849
# 24: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J256.csv
# 25: Beginning detection with contextOSE for P_J280.csv
# . . . . 8: Completed processing 2089 records at 2022-07-23 00:13:27.900698
# 8: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T4.csv
# 9: Beginning detection with contextOSE for P_J302.csv
# . . 25: Completed processing 2089 records at 2022-07-23 00:13:28.280951
# 25: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J280.csv
# 34: Beginning detection with contextOSE for F_PU1.csv
# . . . . . . 34: Completed processing 2089 records at 2022-07-23 00:13:29.584574
# 34: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU1.csv
# 35: Beginning detection with contextOSE for S_PU9.csv
# . . . . 35: Completed processing 2089 records at 2022-07-23 00:13:29.848403
# 35: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU9.csv
# 36: Beginning detection with contextOSE for S_V2.csv
# . 19: Completed processing 2089 records at 2022-07-23 00:13:29.960168
# 19: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J317.csv
# 38: Beginning detection with contextOSE for P_J306.csv
# . 16: Completed processing 2089 records at 2022-07-23 00:13:30.073360
# 16: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J14.csv
# 17: Beginning detection with contextOSE for F_PU2.csv
# . . 26: Completed processing 2089 records at 2022-07-23 00:13:30.326772
# 26: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T2.csv
# 27: Beginning detection with contextOSE for F_PU5.csv
# . . . . 27: Completed processing 2089 records at 2022-07-23 00:13:30.615555
# 27: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU5.csv
# 40: Beginning detection with contextOSE for F_PU8.csv
# . . . . . . 17: Completed processing 2089 records at 2022-07-23 00:13:31.242948
# 17: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU2.csv
# 42: Beginning detection with contextOSE for F_PU11.csv
# . . 30: Completed processing 2089 records at 2022-07-23 00:13:31.445358
# 30: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T3.csv
# 31: Beginning detection with contextOSE for P_J307.csv
# . . . . 40: Completed processing 2089 records at 2022-07-23 00:13:31.950434
# 40: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU8.csv
# 41: Beginning detection with contextOSE for F_PU3.csv
# . . . . 36: Completed processing 2089 records at 2022-07-23 00:13:33.223542
# 36: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_V2.csv
# 37: Beginning detection with contextOSE for F_PU4.csv
# . . . . 38: Completed processing 2089 records at 2022-07-23 00:13:34.467643
# 38: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J306.csv
# 39: Beginning detection with contextOSE for F_PU10.csv
# . . . . . 32: Completed processing 2089 records at 2022-07-23 00:13:37.883782
# 32: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T7.csv
# 33: Beginning detection with contextOSE for S_PU4.csv
# . . . . 28: Completed processing 2089 records at 2022-07-23 00:13:38.892927
# 28: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_L_T6.csv
# 29: Beginning detection with contextOSE for F_PU7.csv
# . . . . .
# Running detection step
# 42: Completed processing 2089 records at 2022-07-23 00:13:31.486781
# 42: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU11.csv
# 41: Completed processing 2089 records at 2022-07-23 00:13:32.575400
# 41: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU3.csv
# 37: Completed processing 2089 records at 2022-07-23 00:13:34.204218
# 37: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU4.csv
# 39: Completed processing 2089 records at 2022-07-23 00:13:36.545309
# 39: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU10.csv
# 9: Completed processing 2089 records at 2022-07-23 00:13:38.997083
# 9: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_P_J302.csv
# 33: Completed processing 2089 records at 2022-07-23 00:13:39.233500
# 33: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_S_PU4.csv
# 29: Completed processing 2089 records at 2022-07-23 00:13:39.658781
# 29: Results have been written to /home/ec2-user/SageMaker/anomaly-detection-spatial-temporal-data/data/07_model_output/iot/ts_result-notebook/contextOSE/contextOSE_F_PU7.csv
#
#
# Done. Results saved under ../../data/07_model_output/iot/ts_result-notebook

# %% [markdown]
# # Load an inference result

# %%
# !ls ../../data/07_model_output/iot/ts_result-notebook/contextOSE/
# Out:
# contextOSE_F_PU10.csv  contextOSE_L_T4.csv    contextOSE_P_J422.csv
# contextOSE_F_PU11.csv  contextOSE_L_T5.csv    contextOSE_S_PU10.csv
# contextOSE_F_PU1.csv   contextOSE_L_T6.csv    contextOSE_S_PU11.csv
# contextOSE_F_PU2.csv   contextOSE_L_T7.csv    contextOSE_S_PU1.csv
# contextOSE_F_PU3.csv   contextOSE_P_J14.csv   contextOSE_S_PU2.csv
# contextOSE_F_PU4.csv   contextOSE_P_J256.csv  contextOSE_S_PU3.csv
# contextOSE_F_PU5.csv   contextOSE_P_J269.csv  contextOSE_S_PU4.csv
# contextOSE_F_PU6.csv   contextOSE_P_J280.csv  contextOSE_S_PU5.csv
# contextOSE_F_PU7.csv   contextOSE_P_J289.csv  contextOSE_S_PU6.csv
# contextOSE_F_PU8.csv   contextOSE_P_J300.csv  contextOSE_S_PU7.csv
# contextOSE_F_PU9.csv   contextOSE_P_J302.csv  contextOSE_S_PU8.csv
# contextOSE_F_V2.csv    contextOSE_P_J306.csv  contextOSE_S_PU9.csv
# contextOSE_L_T1.csv    contextOSE_P_J307.csv  contextOSE_S_V2.csv
# contextOSE_L_T2.csv    contextOSE_P_J317.csv
# contextOSE_L_T3.csv    contextOSE_P_J415.csv

# %%
output_csv = "contextOSE_L_T1.csv"

df_out = pd.read_csv(f"{output_dir}/contextOSE/{output_csv}")

# %%
df_out.head(20)
# Out:
#               timestamp  value  anomaly_score  label
# 0   2017-01-04 00:00:00   0.73            0.0      0
# 1   2017-01-04 01:00:00   0.69            0.0      0
# 2   2017-01-04 02:00:00   0.90            0.0      0
# 3   2017-01-04 03:00:00   1.11            0.0      0
# 4   2017-01-04 04:00:00   1.27            0.0      0
# 5   2017-01-04 05:00:00   1.54            0.0      0
# 6   2017-01-04 06:00:00   1.85            0.0      0
# 7   2017-01-04 07:00:00   2.00            0.0      0
# 8   2017-01-04 08:00:00   2.06            0.0      0
# 9   2017-01-04 09:00:00   2.04            0.0      0
# 10  2017-01-04 10:00:00   1.98            0.0      0
# 11  2017-01-04 11:00:00   1.90            0.0      0
# 12  2017-01-04 12:00:00   2.03            0.0      0
# 13  2017-01-04 13:00:00   2.13            0.0      0
# 14  2017-01-04 14:00:00   2.16            0.0      0
# 15  2017-01-04 15:00:00   2.14            0.0      0
# 16  2017-01-04 16:00:00   2.16            0.0      0
# 17  2017-01-04 17:00:00   2.33            0.0      0
# 18  2017-01-04 18:00:00   2.61            0.0      0
# 19  2017-01-04 19:00:00   2.86            0.0      0

# %% [markdown]
# # References
# Riccardo Taormina and Stefano Galelli and Nils Ole Tippenhauer and Elad Salomons and Avi Ostfeld and Demetrios G. Eliades and Mohsen Aghashahi and Raanju Sundararajan and Mohsen Pourahmadi and M. Katherine Banks and B. M. Brentan and Enrique Campbell and G. Lima and D. Manzi and D. Ayala-Cabrera and M. Herrera and I. Montalvo and J. Izquierdo and E. Luvizotto and Sarin E. Chandy and Amin Rasekh and Zachary A. Barker and Bruce Campbell and M. Ehsan Shafiee and Marcio Giacomoni and Nikolaos Gatsis and Ahmad Taha and Ahmed A. Abokifa and Kelsey Haddad and Cynthia S. Lo and Pratim Biswas and M. Fayzul K. Pasha and Bijay Kc and Saravanakumar Lakshmanan Somasundaram and Mashor Housh and Ziv Ohar; "The Battle Of The Attack Detection Algorithms: Disclosing Cyber Attacks On Water Distribution Networks." Journal of Water Resources Planning and Management, 144 (8), August 2018
#
# Alexander Lavin and Subutai Ahmad. 2015. Evaluating Real-Time Anomaly Detection Algorithms – The Numenta Anomaly Benchmark.
